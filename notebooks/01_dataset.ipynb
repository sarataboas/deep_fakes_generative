# %% [markdown]
# #### **Dataset Description**

# %% [markdown]
# DeepFakeFace(DFF) dataset is generated by various diffusion models, aiming to protect the privacy of celebrities
#
# - inpainting.zip is generated by the Stable Diffusion Inpainting model.
# - insight.zip is generated by the InsightFace toolbox.
# - text2img.zip is generated by Stable Diffusion V1.5
# - wiki.zip contains original real images selected from the IMDB-WIKI dataset.

# %%
data_path = '../data/'

# %% [markdown]
# #### **Label Dataset**

# %% [markdown]
# Dataset preparation for EDA and Model Training (??)
# - label_mapping: {0: fake, 1: real}

# %% [markdown]
# #### **Exploratory Data Analysis**

# %% [markdown]
# 1. **Dataset Overview** : class imbalance, etc...
# 2. **Feature Assessment** : Image resolution distribution, Pixel distribution, Sample visualization, etc...

# %% [markdown]
# #### **Data Preprocessing**

# %% [markdown]
# - Image resizing strategy
# - Normalization
# - Data augmentation (flip, crop, color jitter, blur, etc.)
# - Build PyTorch/TensorFlow Dataset class
# - Implement DataLoader
# - ....
